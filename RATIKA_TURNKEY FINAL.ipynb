# %% [markdown]
# # TURNKEY LENDER CREDIT ANALYSIS

# %% [markdown]
# ### PROBLEM STATMENT
# #### As a data analyst for a credit card company,  analyze  customer data to identify factors that contribute to credit card defaults. The goal should be to  clean and prepare the data, perform exploratory data analysis to identify relationships between variables, and use inferential statistics and hypothesis testing to draw meaningful conclusions about the population based on a sample.

# %%
## Importing all the important libraries required for analysis and EDA
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Credit Dataset for HV Turnkey Lender.csv") ## reading the data set

# %%
df.head()## this will call in top 5 rows
# Out:
#    ID       AMT  GENDER  EDUCATION  MARITAL STATUS  AGE  REPAY_SEP  REPAY_AUG  \
# 0   1   20000.0       2        2.0               1   24          2          2
# 1   2  120000.0       2        2.0               2   26          0          2
# 2   3   90000.0       2        2.0               2   34          0          0
# 3   4   50000.0       2        2.0               1   37          0          0
# 4   5   50000.0       1        2.0               1   57          0          0
#
#    REPAY_JUL  REPAY_JUN  ...  AMTBILL_APR  PRE_SEP  PRE_AUG  PRE_JUL  PRE_JUN  \
# 0          0          0  ...          0.0      0.0    689.0      0.0      0.0
# 1          0          0  ...       3261.0      0.0   1000.0   1000.0   1000.0
# 2          0          0  ...      15549.0   1518.0   1500.0   1000.0   1000.0
# 3          0          0  ...      29547.0   2000.0   2019.0   1200.0   1100.0
# 4          0          0  ...      19131.0   2000.0  36681.0  10000.0   9000.0
#
# ...

# %%
# Check the type of data 
print ("Type : ", type(df), "\n\n") 
  
# Printing Top 10 Records 
print ("Head -- \n", df.head(10)) 
  
# Printing last 10 Records  
print ("\n\n Tail -- \n", df.tail(10))
# Out:
# Type :  <class 'pandas.core.frame.DataFrame'>
#
#
# Head --
#     ID       AMT  GENDER  EDUCATION  MARITAL STATUS  AGE  REPAY_SEP  REPAY_AUG  \
# 0   1   20000.0       2        2.0               1   24          2          2
# 1   2  120000.0       2        2.0               2   26          0          2
# 2   3   90000.0       2        2.0               2   34          0          0
# 3   4   50000.0       2        2.0               1   37          0          0
# 4   5   50000.0       1        2.0               1   57          0          0
# 5   6   50000.0       1        1.0               2   37          0          0
# 6   7  500000.0       1        1.0               2   29          0          0
# 7   8  100000.0       2        2.0               2   23          0          0
# 8   9  140000.0       2        3.0               1   28          0          0
# 9  10   20000.0       1        3.0               2   35          0          0
#
# ...

# %%
df.info() ## This gives in all data for each  column in data set.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              30000 non-null  int64
#  1   AMT             30000 non-null  float64
#  2   GENDER          30000 non-null  int64
#  3   EDUCATION       29986 non-null  float64
#  4   MARITAL STATUS  30000 non-null  int64
#  5   AGE             30000 non-null  int64
#  6   REPAY_SEP       30000 non-null  int64
#  7   REPAY_AUG       30000 non-null  int64
#  8   REPAY_JUL       30000 non-null  int64
#  9   REPAY_JUN       30000 non-null  int64
#  10  REPAY_MAY       30000 non-null  int64
#  11  REPAY_APR       30000 non-null  int64
#  12  AMTBILL_SEP     30000 non-null  float64
#  13  AMTBILL_AUG     30000 non-null  float64
#  14  AMTBILL_JUL     30000 non-null  float64
#  15  AMTBILL_JUN     30000 non-null  float64
#  16  AMTBILL_MAY     30000 non-null  float64
# ...

# %%
# checking the null values
df.isnull().sum()
# Out:
# ID                 0
# AMT                0
# GENDER             0
# EDUCATION         14
# MARITAL STATUS     0
# AGE                0
# REPAY_SEP          0
# REPAY_AUG          0
# REPAY_JUL          0
# REPAY_JUN          0
# REPAY_MAY          0
# REPAY_APR          0
# AMTBILL_SEP        0
# AMTBILL_AUG        0
# AMTBILL_JUL        0
# AMTBILL_JUN        0
# AMTBILL_MAY        0
# AMTBILL_APR        0
# PRE_SEP            0
# PRE_AUG            0
# PRE_JUL            0
# PRE_JUN            0
# PRE_MAY            0
# PRE_APR            0
# DEF_AMT            0
# Sum_Column         0
# Sum_PRE_Column     0
# dtype: int64

# %%
df['EDUCATION'].fillna(0, inplace=True)
print (df)
# Out:
#           ID       AMT  GENDER  EDUCATION  MARITAL STATUS  AGE  REPAY_SEP  \
# 0          1   20000.0       2        2.0               1   24          2
# 1          2  120000.0       2        2.0               2   26          0
# 2          3   90000.0       2        2.0               2   34          0
# 3          4   50000.0       2        2.0               1   37          0
# 4          5   50000.0       1        2.0               1   57          0
# ...      ...       ...     ...        ...             ...  ...        ...
# 29995  29996  220000.0       1        3.0               1   39          0
# 29996  29997  150000.0       1        3.0               2   43          0
# 29997  29998   30000.0       1        2.0               2   37          4
# 29998  29999   80000.0       1        3.0               1   41          1
# 29999  30000   50000.0       1        2.0               1   46          0
#
#        REPAY_AUG  REPAY_JUL  REPAY_JUN  ...  AMTBILL_APR  PRE_SEP  PRE_AUG  \
# ...

# %% [markdown]
# ## Adding a seperate sum  column to  add the total of amount payed by each customer

# %%
# Calculate the sum of columns 'AMTBILL_SEP', 'AMTBILL_AUG', 'AMTBILL_JUL', 'AMTBILL_JUN', 'AMTBILL_MAY','AMTBILL_APR for each row
df['Sum_Column'] = df[['AMTBILL_SEP', 'AMTBILL_AUG', 'AMTBILL_JUL', 'AMTBILL_JUN', 'AMTBILL_MAY','AMTBILL_APR']].sum(axis=1)

# Save the updated DataFrame to a new Excel file
output_excel_file = 'Credit Dataset for HV Turnkey Lender.csv'  # Replace with your desired output file path
df.to_csv('Credit Dataset for HV Turnkey Lender.csv', index=False)

# Display the updated DataFrame
print(df)
# Out:
#           ID       AMT  GENDER  EDUCATION  MARITAL STATUS  AGE  REPAY_SEP  \
# 0          1   20000.0       2        2.0               1   24          2
# 1          2  120000.0       2        2.0               2   26          0
# 2          3   90000.0       2        2.0               2   34          0
# 3          4   50000.0       2        2.0               1   37          0
# 4          5   50000.0       1        2.0               1   57          0
# ...      ...       ...     ...        ...             ...  ...        ...
# 29995  29996  220000.0       1        3.0               1   39          0
# 29996  29997  150000.0       1        3.0               2   43          0
# 29997  29998   30000.0       1        2.0               2   37          4
# 29998  29999   80000.0       1        3.0               1   41          1
# 29999  30000   50000.0       1        2.0               1   46          0
#
#        REPAY_AUG  REPAY_JUL  REPAY_JUN  ...  AMTBILL_APR  PRE_SEP  PRE_AUG  \
# ...

# %% [markdown]
# ### Adding a seperated sum column for calculating the Pre amount of every month for each customer.

# %%
# Calculate the sum of Pre_columns PRE_SEP,'PRE_AUG', 'PRE_JUL', 'PRE_JUN', 'PRE_MAY','PRE_APR for each row
df['Sum_PRE_Column'] = df[['PRE_SEP', 'PRE_AUG', 'PRE_JUL', 'PRE_JUN', 'PRE_MAY','PRE_APR']].sum(axis=1)

# Save the updated DataFrame to a new Excel file
output_excel_file = 'Credit Dataset for HV Turnkey Lender.csv'  # Replace with your desired output file path
df.to_csv('Credit Dataset for HV Turnkey Lender.csv', index=False)

# Display the updated DataFrame
print(df)
# Out:
#           ID       AMT  GENDER  EDUCATION  MARITAL STATUS  AGE  REPAY_SEP  \
# 0          1   20000.0       2        2.0               1   24          2
# 1          2  120000.0       2        2.0               2   26          0
# 2          3   90000.0       2        2.0               2   34          0
# 3          4   50000.0       2        2.0               1   37          0
# 4          5   50000.0       1        2.0               1   57          0
# ...      ...       ...     ...        ...             ...  ...        ...
# 29995  29996  220000.0       1        3.0               1   39          0
# 29996  29997  150000.0       1        3.0               2   43          0
# 29997  29998   30000.0       1        2.0               2   37          4
# 29998  29999   80000.0       1        3.0               1   41          1
# 29999  30000   50000.0       1        2.0               1   46          0
#
#        REPAY_AUG  REPAY_JUL  REPAY_JUN  ...  AMTBILL_APR  PRE_SEP  PRE_AUG  \
# ...

# %% [markdown]
# ####  Now we can easily analyize better the relation between different variables like Amount given as loan, sum of all the amount left to be given , how much outstanding amount is left and the defaulters.

# %%
df.describe()
# Out:
#                  ID             AMT        GENDER     EDUCATION  \
# count  30000.000000    30000.000000  30000.000000  29986.000000
# mean   15000.500000   167484.322667      1.603733      1.852298
# std     8660.398374   129747.661567      0.489129      0.781622
# min        1.000000    10000.000000      1.000000      1.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      5.000000
#
#        MARITAL STATUS           AGE     REPAY_SEP     REPAY_AUG     REPAY_JUL  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean         1.555567     35.485500      0.356767      0.320033      0.304067
# std          0.518833      9.217904      0.760594      0.801727      0.790589
# ...

# %% [markdown]
# ### This code help us to get all the statistical values for each column indiviually. This gives us Mean , Median ,Standard Deviation, maximum etc.

# %% [markdown]
# ### CALCULATING MEAN

# %%
AMT_mean = df.AMT.mean() 
print ("Amount Mean : ", AMT_mean) 
  
AMTBILL_SEP_mean = df.AMTBILL_SEP.mean() 
print ("\nAmount bill of september Mean : ", AMTBILL_SEP_mean) 

AMTBILL_AUG_mean = df.AMTBILL_AUG.mean() 
print ("\nAmount bill of August Mean : ", AMTBILL_AUG_mean) 

AMTBILL_JUN_mean = df.AMTBILL_JUN.mean() 
print ("\nAmount bill of JUNE Mean : ", AMTBILL_JUN_mean) 

AMTBILL_JUL_mean = df.AMTBILL_JUL.mean() 
print ("\nAmount bill of JULY Mean : ", AMTBILL_JUL_mean) 

AMTBILL_MAY_mean = df.AMTBILL_MAY.mean() 
print ("\nAmount bill of MAY Mean : ", AMTBILL_MAY_mean) 

AMTBILL_APR_mean = df.AMTBILL_APR.mean() 
print ("\nAmount bill of APRIL Mean : ", AMTBILL_APR_mean)

# %%
PRE_SEP_mean = df.PRE_SEP.mean() 
print ("PRE_SEPTEMBER MEAN IS  : ", PRE_SEP_mean) 

PRE_AUG_mean = df.PRE_AUG.mean() 
print ("PRE_AUGUST MEAN IS  : ", PRE_AUG_mean) 

PRE_MAY_mean = df.PRE_MAY.mean() 
print ("PRE_MAY MEAN IS  : ", PRE_MAY_mean) 

PRE_JUN_mean = df.PRE_JUN.mean() 
print ("PRE_JUNE MEAN IS  : ", PRE_JUN_mean) 

PRE_JUL_mean = df.PRE_JUL.mean() 
print ("PRE_JULY MEAN IS  : ", PRE_JUL_mean) 

PRE_APR_mean = df.PRE_APR.mean() 
print ("PRE_APRIL MEAN IS  : ", PRE_APR_mean)

# %% [markdown]
# ### CALCULATING THE MEDIAN

# %%
AMT_median = df.AMT.median() 
print ("Amount median : ", AMT_median) 
  
AMTBILL_SEP_median = df.AMTBILL_SEP.median() 
print ("\nAmount bill of september median : ", AMTBILL_SEP_median) 

AMTBILL_AUG_median = df.AMTBILL_AUG.median() 
print ("\nAmount bill of August median : ", AMTBILL_AUG_median) 

AMTBILL_JUN_median = df.AMTBILL_JUN.median() 
print ("\nAmount bill of JUNE median : ", AMTBILL_JUN_median) 

AMTBILL_JUL_median = df.AMTBILL_JUL.median() 
print ("\nAmount bill of JULY median : ", AMTBILL_JUL_median) 

AMTBILL_MAY_median = df.AMTBILL_MAY.median() 
print ("\nAmount bill of MAY median : ", AMTBILL_MAY_median) 

AMTBILL_APR_median = df.AMTBILL_APR.median() 
print ("\nAmount bill of APRIL median : ", AMTBILL_APR_median)

# %%
PRE_AUG_median = df.PRE_AUG.median() 
print ("PRE_AUGUST median IS  : ", PRE_AUG_median) 

PRE_MAY_median = df.PRE_MAY.median() 
print ("PRE_MAY median IS  : ", PRE_MAY_median) 

PRE_JUN_median = df.PRE_JUN.median() 
print ("PRE_JUNE median IS  : ", PRE_JUN_median) 

PRE_JUL_median = df.PRE_JUL.median() 
print ("PRE_JULY median IS  : ", PRE_JUL_median) 

PRE_APR_median = df.PRE_APR.median()
print ("PRE_April median IS  : ", PRE_APR_median)

# %% [markdown]
# ## Droping the duplicate values in the columns

# %%
df_no_duplicates = df.drop_duplicates('AGE')

# Display the DataFrame without duplicates
print("DataFrame without duplicates:")
print(df_no_duplicates)

# %% [markdown]
# #### Calculating the Z score of each columns and finding the outliers

# %%
from scipy import stats

# Define a threshold for Z-score (you can adjust this based on your data)
z_score_threshold = 3

# Identify outliers for each column using Z-score
outliers = pd.DataFrame()
for column in df.columns:
    z_scores = stats.zscore(df[column])
    outliers[column] = df[column][abs(z_scores) > z_score_threshold]

# Display the rows containing outliers
print("Rows with outliers:")
print(outliers)

# %%
# Identify outliers for each column using IQR
outliers_iqr = pd.DataFrame()
for column in df.columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    outliers_iqr[column] = df[column][(df[column] < (Q1 - 1.5 * IQR)) | (df[column] > (Q3 + 1.5 * IQR))]

# Display the rows containing outliers using IQR
print("Rows with outliers (IQR method):")
print(outliers_iqr)
# Out:
# Rows with outliers (IQR method):
#        ID       AMT  GENDER  EDUCATION  MARITAL STATUS  AGE  REPAY_SEP  \
# 12    NaN  630000.0     NaN        NaN             NaN  NaN        NaN
# 433   NaN  580000.0     NaN        NaN             NaN  NaN        NaN
# 451   NaN  600000.0     NaN        NaN             NaN  NaN        2.0
# 527   NaN  620000.0     NaN        NaN             NaN  NaN        2.0
# 555   NaN  630000.0     NaN        NaN             NaN  NaN        NaN
# ...    ..       ...     ...        ...             ...  ...        ...
# 29571 NaN  570000.0     NaN        NaN             NaN  NaN        NaN
# 29740 NaN  620000.0     NaN        NaN             NaN  NaN        NaN
# 29861 NaN  650000.0     NaN        NaN             NaN  NaN        NaN
# 29886 NaN  630000.0     NaN        NaN             NaN  NaN        NaN
# 29963 NaN  610000.0     NaN        NaN             NaN  NaN        NaN
#
#        REPAY_AUG  REPAY_JUL  REPAY_JUN  ...  AMTBILL_APR   PRE_SEP  PRE_AUG  \
# ...

# %% [markdown]
# ## finding the outliers in each column for better understanding .

# %%
# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a boxplot for each column
sns.boxplot(data=df, width=0.5, palette="Set2")

# Add a title and labels
plt.title('Boxplot for Outliers Detection')
plt.xlabel('Columns')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
## THe graph for all the columns 
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))

for column in df.columns:
    sns.histplot(df[column], bins=10, kde=False, label=column)

plt.title('Histograms for Columns')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend(title='Columns')

plt.show()

# %%
# Set the style for seaborn to find the amount used on credit card by different age groups
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AMT', y='AGE', data=df, color='blue', s=100)

# Set plot labels and title
plt.title('Relationship between Age and The AMOUNT ON CREDIT ')
plt.xlabel('AMOUNT ON CREDIT')
plt.ylabel('AGE')

# Display the plot
plt.show()

# %% [markdown]
# ### The maximum credit used is for the age group of 40 - 55 years. Expense is more for this age group people.

# %%
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AGE', y='MARITAL STATUS', data=df, color='blue', s=100)

# Set plot labels and title
plt.title('Relationship between Age and The AMOUNT ON CREDIT ')
plt.xlabel('AMOUNT ON CREDIT')
plt.ylabel('AGE')

# Display the plot
plt.show()

# %% [markdown]
# ### OVER HERE Marital status (1=married, 2=single, 3=others)
# ### So we see that the married people have been using the maximum credit _
# #### This depicts that the expense of married couple is more than the single , others

# %%
##  ploting graph to show relationshi between different parameters:
# Plotting the line graph
# Creating a histogram for 'age'
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.hist(df['AGE'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('AGE')
plt.ylabel('Frequency')

# Creating a histogram for 'default_amount'
plt.subplot(2, 1, 2)
plt.hist(df['DEF_AMT'], bins=10, color='salmon', edgecolor='black')
plt.title('Histogram of Default Amount')
plt.xlabel('Default Amount')
plt.ylabel('Frequency')

# Adjust layout to prevent overlapping
plt.tight_layout()

# Display the plot
plt.show()

# %%
sns.relplot(data=df, x="Sum_Column", y="AMT") ## using seaborn

# %%
sns.relplot(data=df, x="Sum_PRE_Column", y="AMT") ## using seaborn

# %% [markdown]
# ### when we the  last two graph, it is indicated that the maximium amount as paid . The pre amount for the different months is less .
# ### This shows that the customers are willing to pay back the loan within the time .

# %%
# Set the style for seaborn
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AGE', y='Sum_Column', data=df, color='blue', s=100)

# Set plot labels and title
plt.title('Relationship between Age and The amount paid ')
plt.xlabel('Age')
plt.ylabel('Amount paid')

# Display the plot
plt.show()

# %% [markdown]
# #### from this we can see the maximum amount of amount paid lies between 25-65 with maximum amount paid by the customer range id 40-50years.

# %%
# Set the style for seaborn
## DEF_AMT: Default payment (1=yes, 0=no)
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AGE', y='DEF_AMT', data=df, color='blue', s=100)

# Set plot labels and title
plt.title('Relationship between Age and Default amount ')
plt.xlabel('Age')
plt.ylabel('Default amount 1-yes 0-No')

# Display the plot
plt.show()

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sum_Column', y='Sum_PRE_Column', data=df, color='blue', s=100)

# Set plot labels and title
plt.title('Relationship between Amount paid and amount to be paid')
plt.xlabel('Amount paid')
plt.ylabel('Pre Amount to be paid ')

# Display the plot
plt.show()

# %% [markdown]
# ## The above Graph shows the relation between the amount paid and the amount withstanding . As we see relatively the amount left by maximum customer is in range 0 $- 500 $.

# %% [markdown]
# # OBSERVED PROBLEM AND SOLUTION:

# %% [markdown]
# ## 1.THE CREDIT CARD IS ACTIVELY USED BY THE CUSTOMER OF EVERY AGEGROUP FROM 20-75 YEARS.
# ## 2. THE MAXIMUM AMOUNT OF LOAN IS IN THE MID AGE GROUP OF  30 - 45YEAR AND SPECIALLY WHO  ARE MARRIED. WHILE A GOOD CREDIT AMOUNT CAN BE SEEN BY SINGLES AND OTHER BUT DEFAULTERS ARE THE ABOVE ONES.
# ## 3. MOST OF THE CUSTOMER HAD KEPT AMOUNT IN A CYCLIC FORM SO WE SEE GOOD AMOUNT IN PRE_AMOUNT (MONTH) .
# ## 4. THE MAXIMUM AMOUNT BY INDIVIUAL CUSTOMER WAS PAID . ONLY A RANGE OF 100 - 500 DOLLARS WAS OUTSTANDING AMOUNT WHICH LED TO DEFAULT .
# ## 5. THE DEFAUTER AND NON DEFAULTERS ARE MOSTLY IN SAME RANGE WHICH CONCLUDES THAT CUSTOMER LIKES TO KEEP THEIR CYCLE OF CREDIT TO KEEP GOING AND ARE READY FOR DEFAULTER RISK.
