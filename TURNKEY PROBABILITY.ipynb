# %%
## Importing all the important libraries required for analysis and EDA
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Credit Dataset for HV Turnkey Lender.csv") ## reading the data set

# %%
df.head()
# Out:
#    ID       AMT  GENDER  EDUCATION  MARITAL STATUS  AGE  REPAY_SEP  REPAY_AUG  \
# 0   1   20000.0       2        2.0               1   24          2          2
# 1   2  120000.0       2        2.0               2   26          0          2
# 2   3   90000.0       2        2.0               2   34          0          0
# 3   4   50000.0       2        2.0               1   37          0          0
# 4   5   50000.0       1        2.0               1   57          0          0
#
#    REPAY_JUL  REPAY_JUN  ...  AMTBILL_APR  PRE_SEP  PRE_AUG  PRE_JUL  PRE_JUN  \
# 0          0          0  ...          0.0      0.0    689.0      0.0      0.0
# 1          0          0  ...       3261.0      0.0   1000.0   1000.0   1000.0
# 2          0          0  ...      15549.0   1518.0   1500.0   1000.0   1000.0
# 3          0          0  ...      29547.0   2000.0   2019.0   1200.0   1100.0
# 4          0          0  ...      19131.0   2000.0  36681.0  10000.0   9000.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              30000 non-null  int64
#  1   AMT             30000 non-null  float64
#  2   GENDER          30000 non-null  int64
#  3   EDUCATION       29986 non-null  float64
#  4   MARITAL STATUS  30000 non-null  int64
#  5   AGE             30000 non-null  int64
#  6   REPAY_SEP       30000 non-null  int64
#  7   REPAY_AUG       30000 non-null  int64
#  8   REPAY_JUL       30000 non-null  int64
#  9   REPAY_JUN       30000 non-null  int64
#  10  REPAY_MAY       30000 non-null  int64
#  11  REPAY_APR       30000 non-null  int64
#  12  AMTBILL_SEP     30000 non-null  float64
#  13  AMTBILL_AUG     30000 non-null  float64
#  14  AMTBILL_JUL     30000 non-null  float64
#  15  AMTBILL_JUN     30000 non-null  float64
#  16  AMTBILL_MAY     30000 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(20,14))
plt.show()

# %%
# Calculate the sum of columns 'AMTBILL_SEP', 'AMTBILL_AUG', 'AMTBILL_JUL', 'AMTBILL_JUN', 'AMTBILL_MAY','AMTBILL_APR for each row
df['Sum_Column'] = df[['AMTBILL_SEP', 'AMTBILL_AUG', 'AMTBILL_JUL', 'AMTBILL_JUN', 'AMTBILL_MAY','AMTBILL_APR']].sum(axis=1)

# Save the updated DataFrame to a new Excel file
output_excel_file = 'Credit Dataset for HV Turnkey Lender.csv'  # Replace with your desired output file path
df.to_csv('Credit Dataset for HV Turnkey Lender.csv', index=False)

# Display the updated DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Calculate the sum of columns 'AMTBILL_SEP', 'AMTBILL_AUG', 'AMTBILL_JUL', 'AMTBILL_JUN', 'AMTBILL_MAY','AMTBILL_APR for each row
# ----> 2 df['Sum_Column'] = df[['AMTBILL_SEP', 'AMTBILL_AUG', 'AMTBILL_JUL', 'AMTBILL_JUN', 'AMTBILL_MAY','AMTBILL_APR']].sum(axis=1)
#       4 # Save the updated DataFrame to a new Excel file
#       5 output_excel_file = 'Credit Dataset for HV Turnkey Lender.csv'  # Replace with your desired output file path
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Calculate the sum of Pre_columns PRE_SEP,'PRE_AUG', 'PRE_JUL', 'PRE_JUN', 'PRE_MAY','PRE_APR for each row
df['Sum_PRE_Column'] = df[['PRE_SEP', 'PRE_AUG', 'PRE_JUL', 'PRE_JUN', 'PRE_MAY','PRE_APR']].sum(axis=1)

# Save the updated DataFrame to a new Excel file
output_excel_file = 'Credit Dataset for HV Turnkey Lender.csv'  # Replace with your desired output file path
df.to_csv('Credit Dataset for HV Turnkey Lender.csv', index=False)

# Display the updated DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Calculate the sum of Pre_columns PRE_SEP,'PRE_AUG', 'PRE_JUL', 'PRE_JUN', 'PRE_MAY','PRE_APR for each row
# ----> 2 df['Sum_PRE_Column'] = df[['PRE_SEP', 'PRE_AUG', 'PRE_JUL', 'PRE_JUN', 'PRE_MAY','PRE_APR']].sum(axis=1)
#       4 # Save the updated DataFrame to a new Excel file
#       5 output_excel_file = 'Credit Dataset for HV Turnkey Lender.csv'  # Replace with your desired output file path
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df.describe()
# Out:
#                  ID             AMT        GENDER     EDUCATION  \
# count  30000.000000    30000.000000  30000.000000  29986.000000
# mean   15000.500000   167484.322667      1.603733      1.852298
# std     8660.398374   129747.661567      0.489129      0.781622
# min        1.000000    10000.000000      1.000000      1.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      5.000000
#
#        MARITAL STATUS           AGE     REPAY_SEP     REPAY_AUG     REPAY_JUL  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean         1.555567     35.485500      0.356767      0.320033      0.304067
# std          0.518833      9.217904      0.760594      0.801727      0.790589
# ...

# %%
import pandas as pd
from scipy import stats
# Column for which you want to calculate the confidence interval
column_name = 'Sum_PRE_Column'

# Extract the column data
data = df[column_name]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 7
#       4 column_name = 'Sum_PRE_Column'
#       6 # Extract the column data
# ----> 7 data = df[column_name]
#
# TypeError: 'int' object is not subscriptable

# %%
X = df[['AMT','AGE','REPAY_SEP','REPAY_AUG',
        'REPAY_JUL','REPAY_JUN','PRE_JUN','PRE_JUL','PRE_MAY','PRE_APR','Sum_Column','Sum_PRE_Column']]

# %%
pd.get_dummies(X)
# Out:
#             AMT  AGE  REPAY_SEP  REPAY_AUG  REPAY_JUL  REPAY_JUN  PRE_JUN  \
# 0       20000.0   24          2          2          0          0      0.0
# 1      120000.0   26          0          2          0          0   1000.0
# 2       90000.0   34          0          0          0          0   1000.0
# 3       50000.0   37          0          0          0          0   1100.0
# 4       50000.0   57          0          0          0          0   9000.0
# ...         ...  ...        ...        ...        ...        ...      ...
# 29995  220000.0   39          0          0          0          0   3047.0
# 29996  150000.0   43          0          0          0          0    129.0
# 29997   30000.0   37          4          3          2          0   4200.0
# 29998   80000.0   41          1          0          0          0   1926.0
# 29999   50000.0   46          0          0          0          0   1000.0
#
#        PRE_JUL  PRE_MAY  PRE_APR  Sum_Column  Sum_PRE_Column
# ...

# %%
y=df['DEF_AMT']

# %%
from sklearn.preprocessing import LabelEncoder
# Initialising Label encoder
encoder = LabelEncoder()

# %%
encoder.fit(y)
# Out:
# LabelEncoder()

# %%
encoder.transform(y)
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
y_encoded = encoder.transform(y)

# %%
y_encoded = encoder

# %%
encoder.inverse_transform([0])
# Out:
# array([0], dtype=int64)

# %%
### Finding the Poisson for the data set 
from scipy.stats import poisson

# %%
poisson.cdf(1,1)
# Out:
# 0.7357588823428847

# %%
np.random.seed(42)
df = np.random.normal(loc=10, scale=2, size=1000)

# %%
## Finding the binominial Distribution 
from scipy.stats import binom

# %%
binom.pmf(6,16,0,0.24884449755371676)
# Out:
# 0.0

# %%
# Calculate the mean and standard deviation of the data
mean = data.mean()
std_dev = data.std(ddof=1)

# %%
#
 # ddof=1 for sample standard deviation, ddof=0 for population standard deviation

# Set the confidence level (e.g., 95% confidence interval)
confidence_level = 0.95

# Calculate the standard error of the mean
stderr = std_dev / (len(data) ** 0.5)

# Calculate the degrees of freedom
df = len(data) - 1

# Use the t.interval function to calculate the confidence interval
conf_interval = stats.t.interval(confidence_level, df, loc=mean, scale=stderr)

# Display the results
print(f"Mean: {mean}")
print(f"Standard Deviation: {std_dev}")
print(f"Confidence Interval ({confidence_level*100}%): {conf_interval}")
# Out:
# Mean: 0.2212
# Standard Deviation: 0.4150618056909671
# Confidence Interval (95.0%): (0.21650303031147078, 0.22589696968852924)

# %%
## lets conduct the hypothesis testing 
column_name = ' AMTBILL_SEP'

# Extract the column data
data = df[column_name]

# Hypothesized population mean (replace with your specific hypothesis)
hypothesized_mean = 20

# Perform a one-sample t-test
t_stat, p_value = stats.ttest_1samp(data, hypothesized_mean)

# Display the results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Check if the p-value is less than the significance level (e.g., 0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       2 column_name = ' AMTBILL_SEP'
#       4 # Extract the column data
# ----> 5 data = df[column_name]
#       7 # Hypothesized population mean (replace with your specific hypothesis)
#       8 hypothesized_mean = 20
#
# TypeError: 'int' object is not subscriptable

# %%
my_dict = {'key': 'value'}
print(my_dict['key'])
# Out:
# value

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
# Create a contingency table
categorical_columns = ['AMT', 'DEF_AMT']

# %%
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

# %%
contingency_table = pd.crosstab(df[categorical_columns['AMT']], df[categorical_columns['DEF_AMT'
# Out:
#   Cell In[59], line 1
#     contingency_table = pd.crosstab(df[categorical_columns['AMT']], df[categorical_columns['DEF_AMT]])
#                                                                                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# Perform the chi-square test
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

# Display the results
print(f"Chi-square statistic: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Check if the p-value is less than the significance level (e.g., 0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis, there is a significant association between the variables")
else:
    print("Fail to reject the null hypothesis, no significant association detected")
# Out:
# Chi-square statistic: 0.0
# P-value: 1.0
# Degrees of freedom: 1
# Expected frequencies:
# [[2.5 2.5]
#  [2.5 2.5]]
# Fail to reject the null hypothesis, no significant association detected
